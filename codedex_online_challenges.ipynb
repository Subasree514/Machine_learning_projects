# %%
# Sum of Squares https://www.codedex.io/challenges/loops/sum-of-squares
no=int(input())
sqr=[]
tot=int()
for i in range(1,no+1):
  sqr.append(i**2)
tot=sum(sqr)
print(tot)
# Out:
# 55

# %%
# 🧑‍🚀 Planet Weights https://www.codedex.io/challenges/control-flow/planet-weights
rg=[0.38, 0.91, 0.38, 2.53, 1.07, 0.89, 1.14]
planet_number=range(1,8)
def weight_conversion(destination_weight,planet):
    for i in range(0,len(rg)):
        if planet==planet_number[i]:
            destination_weight=weight * rg[i]
            print(destination_weight)
    if planet>=8: 
            print('Invalid planet number')

weight=float(input())
planet=int(input())
weight_conversion(weight,planet)
# Out:
# 19.0

# %%
# ✳️ Asterisks https://www.codedex.io/challenges/loops/asterisks
for i in range(1, 25):
  print('*'*i)
# Out:
# *
# **
# ***
# ****
# *****
# ******
# *******
# ********
# *********
# **********
# ***********
# ************
# *************
# **************
# ***************
# ****************
# *****************
# ******************
# *******************
# ********************
# *********************
# **********************
# ***********************
# ************************

# %%
# 🎲 Snake Eyes https://www.codedex.io/challenges/loops/snake-eyes
import random
total=int()
while total!=2:
  die1 = random.randint(1, 6)
  die2 = random.randint(1, 6)
  total = die1 + die2
  print('Nope')
else:
  print('Snake eyes!')
# Out:
# Nope
# Nope
# Nope
# Nope
# Nope
# Nope
# Nope
# Nope
# Nope
# Nope
# Nope
# Nope
# Nope
# Nope
# Nope
# Nope
# Nope
# Nope
# Nope
# Nope
# Nope
# Nope
# Nope
# Nope
# Nope
# Nope
# Nope
# Nope
# Nope
# Nope
# Nope
# Nope
# Nope
# Nope
# Nope
# Nope
# Nope
# Nope
# Nope
# Nope
# Nope
# Nope
# Nope
# Nope
# Nope
# Nope
# Nope
# Nope
# Nope
# Nope
# Nope
# Nope
# Nope
# Nope
# Nope
# Nope
# Nope
# Nope
# Nope
# Nope
# Nope
# Nope
# Nope
# Nope
# Nope
# Nope
# Nope
# Nope
# Nope
# Nope
# Nope
# Nope
# Nope
# Nope
# Nope
# Nope
# Nope
# Nope
# Nope
# Nope
# Nope
# Nope
# Nope
# Nope
# Nope
# Nope
# Nope
# Nope
# Nope
# Nope
# Nope
# Nope
# Nope
# Nope
# Nope
# Nope
# Nope
# Nope
# Nope
# Nope
# Nope
# Nope
# Nope
# Nope
# Nope
# Nope
# Nope
# Nope
# Nope
# Nope
# Nope
# Nope
# Nope
# Nope
# Nope
# Nope
# Nope
# Nope
# Nope
# Nope
# Nope
# Nope
# Nope
# Nope
# Nope
# Nope
# Nope
# Nope
# Nope
# Nope
# Nope
# Nope
# Nope
# Nope
# Snake eyes!
